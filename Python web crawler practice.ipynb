# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
r = requests.get('https://en.wikipedia.org/wiki/Fable')

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Fable - Wikipedia</title>
# ...

# %%
html = r.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Fable - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.title
# Out:
# <title>Fable - Wikipedia</title>

# %%
soup.p.find_all('a')
# Out:
# [<a href="/wiki/Prose" title="Prose">prose</a>,
#  <a href="/wiki/Verse_(poetry)" title="Verse (poetry)">verse</a>,
#  <a href="/wiki/Animal" title="Animal">animals</a>,
#  <a href="/wiki/Legendary_creature" title="Legendary creature">legendary creatures</a>,
#  <a href="/wiki/Plant" title="Plant">plants</a>,
#  <a href="/wiki/Anthropomorphism" title="Anthropomorphism">anthropomorphized</a>,
#  <a href="/wiki/Moral" title="Moral">moral</a>,
#  <a href="/wiki/Maxim_(philosophy)" title="Maxim (philosophy)">maxim</a>,
#  <a href="/wiki/Saying" title="Saying">saying</a>]

# %%
soup.find(id='mw-content-text').find(class_="mw-parser-output").p.a.get('href')
# Out:
# '/wiki/Prose'

# %%
response = requests.get('https://en.wikipedia.org/wiki/PICALM')
html = response.text
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>PICALM - Wikipedia</title>
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.find(id='mw-content-text').p.a.get('href')
# Out:
# 'https://www.ncbi.nlm.nih.gov/entrez/query.fcgi?db=gene&cmd=retrieve&dopt=default&list_uids=8301&rn=1'

# %%
content_div = soup.find(id="mw-content-text").find(class_="mw-parser-output")
for element in content_div.find_all("p", recursive=False):
    if element.a:
        first_relative_link = element.a.get('href')
        break
print(first_relative_link)
# Out:
# /wiki/Protein
